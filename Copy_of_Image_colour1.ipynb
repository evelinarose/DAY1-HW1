# %% [markdown]
# <a href="https://colab.research.google.com/github/evelinarose/DAY1-HW1/blob/master/Copy_of_Image_colour1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install DeOldify
# !pip install deoldify

# Clone the DeOldify repository
# !git clone https://github.com/jantic/DeOldify.git DeOldify

# Change the working directory
import os
os.chdir('DeOldify')

# Install the required dependencies
# !pip install -r requirements-colab.txt

# Download the DeOldify colorizer model
# !mkdir 'trainingmodel'
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth

# Colorize an image from Google Drive
from deoldify import device
from deoldify.device_id import DeviceId
from deoldify.visualize import *

# choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)

colorizer = get_image_colorizer(artistic=True)

# Path to the input black and white image in Google Drive
input_path = '99e814c1ca80a8402a25b5ddd26b43b4.jpg'
# Colorize the image
colorized_image = colorizer.get_transformed_image(input_path)

# Display the colorized image
show_image_in_notebook(colorized_image, side_by_side=False)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 13.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 20.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 38.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 54.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.8/68.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.3/380.3 kB 34.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 24.5 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
from IPython.display import display
import numpy as np

# Assuming you have the colorized image stored in 'colorized_image' variable as a NumPy array
colorized_image_np = np.array(colorized_image)
colorized_image_pil = Image.fromarray(colorized_image_np)

# Display the image
display(colorized_image_pil)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-db753835fdfc> in <cell line: 6>()
#       4
#       5 # Assuming you have the colorized image stored in 'colorized_image' variable as a NumPy array
# ----> 6 colorized_image_np = np.array(colorized_image)
#       7 colorized_image_pil = Image.fromarray(colorized_image_np)
#       8
#
# NameError: name 'colorized_image' is not defined
